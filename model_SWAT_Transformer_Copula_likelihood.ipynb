# %%
from google.colab import drive
#drive.flush_and_unmount()
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd gdrive/MyDrive/ROBUST_TIME SERIES_CLASSIFICATION/AnomalyBERT-main
# Out:
# /content/gdrive/MyDrive/ROBUST_TIME SERIES_CLASSIFICATION/AnomalyBERT-main

# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
import random
from torch.utils.data import Dataset, DataLoader
from sklearn.preprocessing import MinMaxScaler
# Training loop
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_recall_fscore_support, roc_auc_score, roc_curve
import matplotlib.pyplot as plt
from torch.distributions import MultivariateNormal
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader
import random
from sklearn.metrics import precision_recall_fscore_support, accuracy_score, roc_curve, auc
from torch.nn.utils.rnn import pad_sequence

# %%
data_norm_anom = pd.read_csv('/content/gdrive/MyDrive/DATASETS/TIME_SERIES_MULTI_V_DATA/SWAT_NORMALIZED.csv')
#data_norm_anom = pd.read_csv('/content/gdrive/MyDrive/DATASETS/TIME_SERIES_MULTI_V_DATA/WADI/WADI_NORMALIZED_DATA.csv')
data_norm_anom = data_norm_anom.iloc[0:100000]
data_norm_anom = data_norm_anom.dropna()

df_normal = data_norm_anom[data_norm_anom['Label'] == 0]
df_normal = df_normal.iloc[:, 0:-1]
df_normal.shape
# Out:
# (93873, 26)

# %%
data_norm_anom = pd.read_csv('/content/gdrive/MyDrive/DATASETS/TIME_SERIES_MULTI_V_DATA/SWAT_NORMALIZED.csv')
#data_norm_anom = pd.read_csv('/content/gdrive/MyDrive/DATASETS/TIME_SERIES_MULTI_V_DATA/WADI/WADI_NORMALIZED_DATA.csv')
data_norm_anom = data_norm_anom.iloc[0:20000]
data_norm_anom = data_norm_anom.dropna()

df_anomaly = data_norm_anom[data_norm_anom['Label'] == 1]
df_anomaly = df_anomaly.iloc[:, 0:-1]
df_anomaly.shape
# Out:
# (4466, 26)

# %%
df_anomaly = df_anomaly.values
df_anomaly.shape
# Out:
# (4466, 26)

# %%
df_normal = df_normal.values
df_normal.shape
# Out:
# (93873, 26)

# %%
import numpy as np
import random

class SyntheticAnomalyGenerator:
    def __init__(self,
                 window_size,
                 reference_anomalies,
                 anomaly_types=['local_perturbation']):
        """
        Initializes the anomaly generator that oversamples real anomaly data
        but applies small perturbations to create a local neighborhood around
        the real anomalies.

        Args:
            window_size (int): The size of the anomaly window to inject.
            reference_anomalies (np.ndarray): Real anomaly data from which to oversample.
              Shape could be (num_anomalies, sequence_length, num_features) or
              (num_anomalies, num_features) if each row is a snippet, etc.
            anomaly_types (list): We keep it flexible, but default to ['local_perturbation'].
        """
        self.anomaly_types = anomaly_types
        self.window_size = window_size

        # Real anomaly data to oversample from
        self.reference_anomalies = reference_anomalies

    def inject_anomaly_into_sequence(self, sequence):
        """
        Called externally to inject an anomaly into 'sequence' by
        picking a real anomaly snippet, perturbing it, and overlaying.
        """
        anomalous_sequence = sequence.copy()
        anomaly_type = random.choice(self.anomaly_types)

        seq_length, num_features = anomalous_sequence.shape

        if seq_length <= self.window_size:
            t0 = 0
            t1 = seq_length
        else:
            t0 = random.randint(0, seq_length - self.window_size)
            t1 = t0 + self.window_size

        if anomaly_type == 'local_perturbation':
            anomalous_sequence = self.local_perturbation_injection(anomalous_sequence, t0, t1)
        elif anomaly_type == 'permutation_anomaly':
            # optional, if you want partial permutations
            anomalous_sequence = self.permutation_anomaly(anomalous_sequence, t0, t1)

        return anomalous_sequence

    def local_perturbation_injection(self, sequence, t0, t1):
        """
        1) Randomly pick a real anomaly snippet from reference_anomalies.
        2) Possibly adapt or clamp it to 'window_size'.
        3) Add small random perturbations (noise, slight scaling, partial permutations, etc.).
        4) Overlay onto 'sequence[t0:t1]'.
        """
        anomalous_sequence = sequence.copy()
        window_length = t1 - t0
        seq_length, num_features = anomalous_sequence.shape

        # 1) pick a random anomaly snippet from reference_anomalies
        #    Suppose reference_anomalies has shape (num_anomalies, anomaly_length, num_features)
        #    or (num_anomalies, num_features) if each row is a snippet.
        rand_idx = random.randint(0, self.reference_anomalies.shape[0]-1)
        real_anomaly_snippet = self.reference_anomalies[rand_idx]

        # Check if real_anomaly_snippet is 2D or 1D
        if real_anomaly_snippet.ndim == 1:
            # shape (num_features,) => we replicate or clamp it
            # e.g. we'll just tile it for 'window_length'
            real_anomaly_snippet = np.tile(real_anomaly_snippet, (window_length,1))
        elif real_anomaly_snippet.shape[0] != window_length:
            # We do a clamp or pad approach:
            real_len = real_anomaly_snippet.shape[0]
            if real_len > window_length:
                # clamp
                start_ = random.randint(0, real_len - window_length)
                real_anomaly_snippet = real_anomaly_snippet[start_:start_+window_length, :]
            else:
                # if real_len < window_length => pad repeats or edge
                repeats_needed = window_length - real_len
                # simplest => tile or pad
                real_anomaly_snippet = np.concatenate([
                    real_anomaly_snippet,
                    np.tile(real_anomaly_snippet[-1,:], (repeats_needed,1))
                ], axis=0)

        # Now real_anomaly_snippet is shape (window_length, num_features)

        # 2) Add small perturbations
        perturbed_snippet = self.apply_small_perturbations(real_anomaly_snippet)

        # 3) Overlay
        anomalous_sequence[t0:t1] = perturbed_snippet
        return anomalous_sequence

    def apply_small_perturbations(self, snippet):
        """
        snippet shape: (window_length, num_features)
        We'll do e.g.:
          - small gaussian noise
          - slight random scaling per feature
          - partial permutations of a few rows (rare)
        all to keep changes mild.
        """
        w_len, n_feats = snippet.shape
        snippet_ = snippet.copy()

        # A) small gaussian noise
        noise_std = 0.05 * np.std(snippet_)  # e.g. 5% of snippet's std
        noise = np.random.normal(0, noise_std, snippet_.shape)
        snippet_ += noise

        # B) slight random scaling per feature
        # e.g. each feature f => scale_f in [0.95,1.05]
        scales = 0.95 + 0.1*np.random.rand(n_feats)
        for f in range(n_feats):
            snippet_[:, f] *= scales[f]

        # C) partial row permutation, only a few rows
        # e.g. we permute 10% of the snippet rows:
        row_count = int(0.1 * w_len)  # 10% of rows
        if row_count>1:
            perm_indices = np.random.choice(w_len, size=row_count, replace=False)
            # shuffle those rows
            snippet_[perm_indices] = snippet_[np.random.permutation(perm_indices)]

        return snippet_

    def permutation_anomaly(self, sequence, t0, t1):
        """
        If you want a direct 'permutation_anomaly' approach:
        """
        anomalous_sequence = sequence.copy()
        window = anomalous_sequence[t0:t1]
        perm_indices = np.random.permutation(len(window))
        permuted_window = window[perm_indices]
        anomalous_sequence[t0:t1] = permuted_window
        return anomalous_sequence

# %%
def extract_sequences(time_series_data, window_size, step_size):
    total_length, num_features = time_series_data.shape
    sequences = []

    for start_idx in range(0, total_length - window_size + 1, step_size):
        end_idx = start_idx + window_size
        sequence = time_series_data[start_idx:end_idx]
        sequences.append(sequence)

    return sequences

# %%
def generate_consecutive_pairs(sequences, sequence_labels):
    """
    Generate pairs of consecutive sequences.

    Args:
        sequences (list): List of sequences.
        sequence_labels (list): Corresponding labels for each sequence.

    Returns:
        x1_pairs (list): List of sequences for x1.
        x2_pairs (list): List of sequences for x2.
        pair_labels (list): List of labels for each pair (0 for normal-normal, 1 for anomaly-involved).
    """
    x1_pairs = []
    x2_pairs = []
    pair_labels = []

    for i in range(len(sequences) - 1):
        x1 = sequences[i]
        x2 = sequences[i + 1]
        label = 0  # Default to normal-normal

        # If either sequence is anomalous, label the pair as anomaly-involved
        if sequence_labels[i] == 1 or sequence_labels[i + 1] == 1:
            label = 1

        x1_pairs.append(x1)
        x2_pairs.append(x2)
        pair_labels.append(label)

    return x1_pairs, x2_pairs, pair_labels

# %%
def collate_fn(batch):
    x1_batch, x2_batch, labels = zip(*batch)

    x1_batch = [torch.tensor(x, dtype=torch.float32) for x in x1_batch]
    x2_batch = [torch.tensor(x, dtype=torch.float32) for x in x2_batch]

    x1_lengths = torch.tensor([seq.size(0) for seq in x1_batch], dtype=torch.long)
    x2_lengths = torch.tensor([seq.size(0) for seq in x2_batch], dtype=torch.long)

    padded_x1 = pad_sequence(x1_batch, batch_first=True, padding_value=0.0)
    padded_x2 = pad_sequence(x2_batch, batch_first=True, padding_value=0.0)

    labels = torch.tensor(labels, dtype=torch.float32)  # For contrastive loss, labels should be float

    max_len_x1 = padded_x1.size(1)
    max_len_x2 = padded_x2.size(1)

    range_x1 = torch.arange(max_len_x1).unsqueeze(0).expand(len(x1_lengths), max_len_x1)
    range_x2 = torch.arange(max_len_x2).unsqueeze(0).expand(len(x2_lengths), max_len_x2)

    x1_mask = (range_x1 >= x1_lengths.unsqueeze(1)).to(torch.bool)
    x2_mask = (range_x2 >= x2_lengths.unsqueeze(1)).to(torch.bool)

    return padded_x1, padded_x2, labels, x1_mask, x2_mask

# %%
def apply_synthetic_anomalies_to_sequences(sequences, anomaly_percentage, anomaly_generator):
    """
    Inject synthetic anomalies into a specified percentage of sequences.

    Args:
        sequences (list): List of sequences extracted from the time series data.
        anomaly_percentage (float): Percentage of sequences to inject anomalies (0.1 to 1.0).
        anomaly_generator (SyntheticAnomalyGenerator): An instance of the anomaly generator.

    Returns:
        augmented_sequences (list): List of sequences after injecting anomalies.
        sequence_labels (list): Labels for each sequence (0 for normal, 1 for anomaly).
    """
    num_sequences = len(sequences)
    num_anomalous_sequences = int(num_sequences * anomaly_percentage)
    anomaly_indices = set(random.sample(range(num_sequences), num_anomalous_sequences))

    augmented_sequences = []
    sequence_labels = []

    for i, seq in enumerate(sequences):
        if i in anomaly_indices:
            # Inject anomaly into the entire sequence
            augmented_seq = anomaly_generator.inject_anomaly_into_sequence(seq)
            augmented_sequences.append(augmented_seq)
            sequence_labels.append(1)
        else:
            # Normal sequence
            augmented_sequences.append(seq)
            sequence_labels.append(0)

    return augmented_sequences, sequence_labels

# %%
import torch
from torch.utils.data import Dataset

class TimeSeriesDataset(Dataset):
    def __init__(self, x1_pairs, x2_pairs, pair_labels, transform=None):
        assert len(x1_pairs) == len(x2_pairs) == len(pair_labels), "All inputs must have the same length."
        self.x1_pairs = x1_pairs
        self.x2_pairs = x2_pairs
        self.pair_labels = pair_labels
        self.transform = transform

    def __len__(self):
        return len(self.pair_labels)

    def __getitem__(self, idx):
        x1 = self.x1_pairs[idx]
        x2 = self.x2_pairs[idx]
        label = self.pair_labels[idx]

        if self.transform:
            x1 = self.transform(x1)
            x2 = self.transform(x2)

        return x1, x2, label

# %%
class TransformerEncoder(nn.Module):
    def __init__(self, input_dim, model_dim, num_heads, num_layers, dropout):
        super(TransformerEncoder, self).__init__()
        self.input_proj = nn.Linear(input_dim, model_dim)
        encoder_layer = nn.TransformerEncoderLayer(
            d_model=model_dim, nhead=num_heads, dropout=dropout, batch_first=True
        )
        self.transformer_encoder = nn.TransformerEncoder(
            encoder_layer, num_layers=num_layers
        )
        self.output_proj = nn.Linear(model_dim, model_dim)
        self.activation = nn.ReLU()
        self.dropout = nn.Dropout(dropout)

    def forward(self, x, src_key_padding_mask=None):
        x = self.input_proj(x)  # (batch_size, seq_length, model_dim)
        x = self.dropout(x)
        x = self.transformer_encoder(x, src_key_padding_mask=src_key_padding_mask)  # (batch_size, seq_length, model_dim)

        if src_key_padding_mask is not None:
            # Create data mask: True where data is present
            data_mask = (~src_key_padding_mask).unsqueeze(2).type_as(x)  # (batch_size, seq_length, 1)
            x = x * data_mask  # Zero out padding positions: (batch_size, seq_length, model_dim)
            x_sum = x.sum(dim=1)  # Sum over seq_length: (batch_size, model_dim)

            lengths = data_mask.sum(dim=1)  # Sum over seq_length: (batch_size, 1)
            lengths = lengths.clamp(min=1)  # Avoid division by zero
            x = x_sum / lengths  # (batch_size, model_dim)
        else:
            x = x.mean(dim=1)  # Average over seq_length: (batch_size, model_dim)

        x = self.output_proj(x)  # (batch_size, model_dim)
        x = self.activation(x)
        return x

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.distributions import Normal, MultivariateNormal
from torch.special import gammaln
import math
from scipy.stats import t as scipy_t

def _student_t_univ_logpdf(x, nu):
    d = 1.0
    c1 = gammaln(0.5*(nu + d)) - gammaln(0.5*nu)
    c2 = -0.5 * math.log(nu * math.pi)
    return c1 + c2 - 0.5*(nu + d)*torch.log1p(x.pow(2)/nu)

def _multivariate_student_t_logpdf(v, L, nu):
    # see above for derivation
    batch, d = v.shape
    sol = torch.linalg.solve_triangular(L, v.unsqueeze(-1), upper=False)
    mahal = (sol.squeeze(-1)**2).sum(1)
    diagL = torch.diagonal(L)
    logdet = 2 * torch.log(diagL).sum()
    c = (
        gammaln(0.5*(nu + d))
        - gammaln(0.5*nu)
        - 0.5*d*math.log(nu*math.pi)
        - 0.5*logdet
    )
    return c - 0.5*(nu + d)*torch.log1p(mahal/nu)

def _build_cholesky_from_params(params, d, device, dtype, eps=1e-6):
    """
    Build a lower-triangular L from a flat `params` tensor
    **without any in-place ops** so that gradients flow cleanly.
    """
    # tril indices
    idx = torch.tril_indices(d, d, 0, device=device)
    # scatter into a sparse → dense
    L_raw = torch.sparse_coo_tensor(idx, params, (d, d), dtype=dtype, device=device).to_dense()
    # apply softplus to the diagonal
    raw_diag = L_raw.diagonal()
    diag = F.softplus(raw_diag) + eps
    off  = L_raw - torch.diag_embed(raw_diag)
    return off + torch.diag_embed(diag)

class GaussianCopula(nn.Module):
    """
    True Gaussian copula log-density:
        log c(u) = log φ_d(v; Σ)  –  ∑ log φ₁(v_i)
    """
    def __init__(self, latent_dim):
        super().__init__()
        self.d = latent_dim
        n_tril = (latent_dim * (latent_dim+1)) // 2
        self.L_params = nn.Parameter(torch.randn(n_tril) * 0.1)

    def forward(self, z, mu=None, std=None):
        eps = 1e-6
        batch, d = z.shape
        # 1) standardize
        if mu is None or std is None:
            mu_  = z.mean(0, keepdim=True)
            std_ = z.std(0, keepdim=True, unbiased=False) + eps
        else:
            mu_, std_ = mu, std
        z_std = (z - mu_) / std_
        # 2) PIT → uniform via Gaussian CDF
        u = Normal(0,1).cdf(z_std).clamp(eps, 1-eps)
        # 3) inverse CDF → v
        v = Normal(0,1).icdf(u)
        # 4) build Σ = L Lᵀ
        L = _build_cholesky_from_params(self.L_params, d, z.device, z.dtype, eps)
        # 5a) joint φ_d
        mvn = MultivariateNormal(torch.zeros(d,device=z.device), scale_tril=L)
        joint = mvn.log_prob(v)
        # 5b) marginals φ₁
        marg  = Normal(0,1).log_prob(v).sum(1)
        return joint - marg

class StudentTCopula(nn.Module):
    """
    True Student-t copula log-density:
        log c(u) = log f_{t,d,ν}(v; Σ)  –  ∑ log f_{t,1,ν}(v_i)
    """
    def __init__(self, latent_dim):
        super().__init__()
        self.d = latent_dim
        n_tril = (latent_dim * (latent_dim+1)) // 2
        self.L_params = nn.Parameter(torch.randn(n_tril) * 0.1)
        self.nu_param = nn.Parameter(torch.tensor(5.0))

    def _nu(self):
        return F.softplus(self.nu_param) + 1e-4

    def forward(self, z, mu=None, std=None):
        eps = 1e-6
        batch, d = z.shape
        nu = self._nu()
        # 1) standardize
        if mu is None or std is None:
            mu_  = z.mean(0, keepdim=True)
            std_ = z.std(0, keepdim=True, unbiased=False) + eps
        else:
            mu_, std_ = mu, std
        z_std = (z - mu_) / std_
        # 2) PIT via Student-t CDF (SciPy)
        u_np = scipy_t.cdf(z_std.detach().cpu().numpy(), df=nu.item())
        u    = torch.from_numpy(u_np).to(device=z.device, dtype=z.dtype).clamp(eps,1-eps)
        # 3) inverse PPF → v
        v_np = scipy_t.ppf(u_np, df=nu.item())
        v    = torch.from_numpy(v_np).to(device=z.device, dtype=z.dtype)
        # 4) build Σ = L Lᵀ
        L = _build_cholesky_from_params(self.L_params, d, z.device, z.dtype, eps)
        # 5) joint vs marginals
        joint = _multivariate_student_t_logpdf(v, L, nu)
        marg  = _student_t_univ_logpdf(v, nu).sum(1)
        return joint - marg

# %%
import torch.nn.functional as F

def contrastive_loss(ll_gaussian, ll_vine, pair_labels, alpha=0.5, base_margin= 0.0):
    """
      A contrastive loss for separating normal vs. anomaly log-likelihoods with a *dynamic* margin:

      1) Normal frames => maximize log-likelihood => loss = -LL_normal
      2) Anomaly frames => LL_anomaly <= (mean_normal_LL - base_offset) on a per-sample basis.

    Now we receive both Gaussian and Studen-t LL. We pick the appropriate LL based on the labels:
    - Normal pairs (label=0) -> Gaussian Copula LL
    - Anomaly pairs (label=1) -> Vine Copula LL
    """
    pair_labels = pair_labels.view(-1)
    # Select appropriate LL based on labels
    chosen_ll = torch.where(pair_labels == 0, ll_gaussian, ll_vine)

    normal_ll = chosen_ll[pair_labels == 0]
    anomaly_ll = chosen_ll[pair_labels == 1]
    #print (f"Normal LL: {normal_ll.mean()}")
    #print (f"Anomaly LL: {anomaly_ll.mean()}")

    if len(normal_ll) > 0:
        loss_normal = -normal_ll
        mean_normal_ll = normal_ll.mean()
    else:
        loss_normal = torch.tensor(0.0, device=chosen_ll.device)
        mean_normal_ll = torch.tensor(0.0, device=chosen_ll.device)

    # -----------------------
    # Anomaly portion
    # -----------------------
    # We'll define a *dynamic margin* for anomalies
    # margin_dyn = mean_normal_ll - base_offset
    # Then for each anomaly sample 'a', we want a <= margin_dyn => diff = a - margin_dyn => F.relu(diff)
    # If diff>0 => penalty
    if len(anomaly_ll) > 0:
        margin_dyn = mean_normal_ll - base_margin
        # shape (#anomalies,)
        diff = anomaly_ll - margin_dyn
        # sample-level margin
        loss_anomaly = alpha * F.relu(diff).mean()
    else:
        loss_anomaly = torch.tensor(0.0, device=device)

    total_loss = (1 - alpha) * loss_normal.mean() + loss_anomaly.mean()


      # Monitoring: Print average log-likelihoods for debugging
    if len(normal_ll) > 0:
        print(f"Contrastive Loss - Normal LL Mean: {loss_normal.mean().item():.4f}")
    else:
        print("Contrastive Loss - No Normal Samples in Batch.")

    if len(anomaly_ll) > 0:
        print(f"Contrastive Loss - Anomalous LL Mean: {loss_anomaly.mean().item():.4f}")
    else:
        print("Contrastive Loss - No Anomalous Samples in Batch.")

    return total_loss

# %%
class AnomalyTransformer(nn.Module):
    def __init__(self, input_dim, model_dim, num_heads, num_layers, dropout, embedding_dim=64):
        super(AnomalyTransformer, self).__init__()
        self.encoder = TransformerEncoder(input_dim, model_dim, num_heads, num_layers, dropout)

        # We now have two different copulas
        #self.gaussian_copula = StudentTCopula_Normal(latent_dim=2 * model_dim)
        #self.vine_copula = StudentTCopula_Anomaly(latent_dim=2 * model_dim)

        self.gaussian_copula = StudentTCopula(latent_dim=2*model_dim)
        self.vine_copula     = StudentTCopula(latent_dim=2*model_dim)


        self.embedding_layer = nn.Linear(2 * model_dim, embedding_dim)

    def forward(self, x1, x2, mask1=None, mask2=None):
        z1 = self.encoder(x1, src_key_padding_mask=mask1)
        z2 = self.encoder(x2, src_key_padding_mask=mask2)
        z = torch.cat((z1, z2), dim=1)

        # Compute both Gaussian and Vine likelihoods
        ll_gaussian = self.gaussian_copula(z)
        ll_vine = self.vine_copula(z)
        return ll_gaussian, ll_vine

    def get_embeddings(self, x1, x2, mask1=None, mask2=None):
        # Instead of passing x1, x2 as (B, features),
        # we do x1 => (B, 1, features)
        if x1.dim() == 2:
            x1 = x1.unsqueeze(1)  # shape => (B,1,features)
        if x2.dim() == 2:
            x2 = x2.unsqueeze(1)

        transformed_x1 = self.encoder(x1, src_key_padding_mask=mask1)
        transformed_x2 = self.encoder(x2, src_key_padding_mask=mask2)

        # Now each is likely shape (B, seq_len=1, model_dim) or (B, model_dim)
        # if the encoder does a mean over seq_len => shape (B, model_dim).
        # We need to confirm the final shape. If the encoder returns 3D => e.g. (B,1,model_dim),
        # we might want to reduce it to 2D => (B,model_dim) by mean over dim=1.
        if transformed_x1.dim() == 3:
            # e.g. if shape => (B,1,hidden_dim), reduce to (B, hidden_dim)
            transformed_x1 = transformed_x1.mean(dim=1)
        if transformed_x2.dim() == 3:
            transformed_x2 = transformed_x2.mean(dim=1)

        # Now each => (B, hidden_dim)
        combined = torch.cat((transformed_x1, transformed_x2), dim=1)  # => (B,2*hidden_dim)
        embeddings = self.embedding_layer(combined)  # => (B, embed_dim)
        return embeddings

# %%
#

# %%
window_size = 100
step_size = 50  # Non-overlapping sequences
anomaly_percentage = 0.7 # 20% of sequences will be anomalous
batch_size = 64


# Step 1: Extract sequences from the raw data
sequences = extract_sequences(df_normal, window_size=window_size, step_size=step_size)
print(f"Total extracted sequences: {len(sequences)}")


anomaly_generator = SyntheticAnomalyGenerator(
    window_size=50,
    reference_anomalies=df_anomaly,
    anomaly_types=['local_perturbation']  # can add 'permutation_anomaly' if desired
)

# Step 2: Inject anomalies into sequences
augmented_sequences, sequence_labels = apply_synthetic_anomalies_to_sequences(
    sequences,
    anomaly_percentage=anomaly_percentage,
    anomaly_generator=anomaly_generator
)
print(f"Total anomalous sequences: {sum(sequence_labels)}")

# Step 3: Generate consecutive pairs
x1_pairs, x2_pairs, pair_labels = generate_consecutive_pairs(augmented_sequences, sequence_labels)
print(f"Total generated pairs: {len(pair_labels)}")
print(f"Anomaly-involved pairs: {sum(pair_labels)}")
print(f"Normal-normal pairs: {len(pair_labels) - sum(pair_labels)}")
# Out:
# Total extracted sequences: 1876
# Total anomalous sequences: 1313
# Total generated pairs: 1875
# Anomaly-involved pairs: 1712
# Normal-normal pairs: 163

# %%
from torch.utils.data import DataLoader, Subset
import torch

# 1) Train dataset from x1_pairs, x2_pairs, pair_labels
train_dataset = TimeSeriesDataset(
    x1_pairs=x1_pairs,
    x2_pairs=x2_pairs,
    pair_labels=pair_labels,
    transform=None
)

train_loader = DataLoader(
    train_dataset,
    batch_size=64,
    shuffle=True,
    num_workers=4,
    collate_fn=collate_fn
)

# %%
# 2) Build a new dataset for the separate test data
import pandas as pd
data_norm_anom = pd.read_csv('/content/gdrive/MyDrive/DATASETS/TIME_SERIES_MULTI_V_DATA/SWAT_NORMALIZED.csv')
data_norm_anom = data_norm_anom.dropna()

data_test = data_norm_anom.iloc[100000:200000]
test_features = data_test.iloc[:, :-1].values
test_labels   = data_test.iloc[:,  -1].values
print (test_features.shape, test_labels.shape)
# Out:
# (100000, 26) (100000,)

# %%
# Define a simple dataset
class SimpleTimeSeriesDataset(torch.utils.data.Dataset):
    def __init__(self, features, labels, transform=None):
        self.features = features
        self.labels   = labels
        self.transform= transform
    def __len__(self):
        return len(self.labels)
    def __getitem__(self, idx):
        x = self.features[idx]
        y = self.labels[idx]
        if self.transform:
            x = self.transform(x)
        return x, y

test_dataset_all = SimpleTimeSeriesDataset(test_features, test_labels)

# %%
import numpy as np
from torch.utils.data import Subset

# assume test_labels is your full chronological array of 0/1 labels
N = len(test_labels)
val_size = N // 2

# 1) find the indices of each class
normal_idx = np.where(test_labels == 0)[0]   # e.g. array of all normal positions
anom_idx   = np.where(test_labels == 1)[0]   # array of all anomaly positions

# 2) decide how many of each go into the val fold,
#    but don’t request more anomalies than you actually have
nom_needed = val_size - min(len(anom_idx), int(val_size * len(anom_idx) / N))
anom_needed = min(len(anom_idx), val_size - nom_needed)

# 3) slice off that many from the start of each index list
val_norm_inds = normal_idx[:nom_needed]
val_anom_inds = anom_idx[:anom_needed]

# 4) combine and sort so that chronology within val is preserved
val_inds = np.sort(np.concatenate([val_norm_inds, val_anom_inds]))

# 5) the remaining indices become your test set
test_norm_inds = normal_idx[nom_needed:]
test_anom_inds = anom_idx[anom_needed:]
test_inds = np.sort(np.concatenate([test_norm_inds, test_anom_inds]))

# 6) build your subsets exactly as before
val_subset  = Subset(test_dataset_all, val_inds.tolist())
test_subset = Subset(test_dataset_all, test_inds.tolist())

val_loader = DataLoader(val_subset,  batch_size=64, shuffle=False, num_workers=4)
test_loader= DataLoader(test_subset, batch_size=64, shuffle=False, num_workers=4)

# no more SyntheticAnomalyGenerator here, either
# test_ds = WindowedDataset(
#     features   = Xtest,
#     labels     = ytest,
#     window_size= L,
#     stride     = 1,
#     min_anoms  = k   # if you want “at least k points in a window”
# )
#test_loader = DataLoader(test_ds, batch_size=64, shuffle=False)


# 7) now you can index into test_labels safely:
val_true_ts = test_labels[val_inds]  # contains both 0’s and 1’s
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
input_dim = df_normal.shape[1]  # Number of features in the input data
model_dim = 32#128 #64
num_heads = 4
num_layers = 2
dropout = 0.3

model = AnomalyTransformer(input_dim=input_dim, model_dim=model_dim, num_heads=num_heads, num_layers=num_layers, dropout=dropout).to(device)
optimizer = optim.Adam(model.parameters(), lr=1e-4)

# %% [markdown]
# **PLOTTING AND STATS**

# %%
import numpy as np

def compute_add(true_ts_labels, window_size, window_preds, stride=1):
    """
    true_ts_labels: 1D array of 0/1 at every timestamp (length T)
    window_size:    number of timestamps per window (L)
    window_preds:   1D array of 0/1 window‐level predictions (length N)
    stride:         step between windows (default 1)
    """
    # 1. find all ground‐truth anomaly events
    events = []
    in_event = False
    for t, y in enumerate(true_ts_labels):
        if y and not in_event:
            start = t
            in_event = True
        if in_event and not y:
            events.append((start, t-1))
            in_event = False
    if in_event:
        events.append((start, len(true_ts_labels)-1))

    # 2. map each window index → its end‐time in the original timeline
    window_ends = [i*stride + window_size - 1 for i in range(len(window_preds))]

    # 3. for each event, find first flagged window and compute delay
    delays = []
    for (start, _) in events:
        # windows whose end ≥ event start and prediction == 1
        candidates = [we for we, p in zip(window_ends, window_preds) if p and we >= start]
        if candidates:
            delays.append(min(candidates) - start)
        # else: you never detected that event (you can drop or assign a large penalty)
    return np.mean(delays) if delays else np.nan

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
import numpy as np
import torch

# Function to calculate F1_PA
def calculate_f1_pa(labels, preds):
    true_segments = []
    pred_segments = []

    # Get segments for true labels
    i = 0
    while i < len(labels):
        if labels[i] == 1:
            start = i
            while i < len(labels) and labels[i] == 1:
                i += 1
            true_segments.append((start, i - 1))
        i += 1

    # Get segments for predictions
    i = 0
    while i < len(preds):
        if preds[i] == 1:
            start = i
            while i < len(preds) and preds[i] == 1:
                i += 1
            pred_segments.append((start, i - 1))
        i += 1

    # Compute overlap
    tp = 0
    for t_start, t_end in true_segments:
        for p_start, p_end in pred_segments:
            if not (p_end < t_start or p_start > t_end):
                tp += 1
                break

    precision_pa = tp / len(pred_segments) if len(pred_segments) > 0 else 0
    recall_pa = tp / len(true_segments) if len(true_segments) > 0 else 0
    f1_pa = 2 * precision_pa * recall_pa / (precision_pa + recall_pa) if precision_pa + recall_pa > 0 else 0

    return f1_pa

# %%
def validate(model, val_loader, device, threshold=None,
             window_size=None, true_ts_labels=None, stride=1):
    model.eval()
    all_ll, all_labels = [], []

    with torch.no_grad():
        for batch in val_loader:
            if len(batch) == 5:
                x1, x2, labels, m1, m2 = batch
                x1, x2 = x1.to(device), x2.to(device)
                labels  = labels.to(device)
                m1, m2  = m1.to(device), m2.to(device)
                ll_g, ll_v = model(x1, x2, mask1=m1, mask2=m2)

            elif len(batch) == 3:
                x1, x2, labels = batch
                x1, x2 = x1.to(device), x2.to(device)
                labels = labels.to(device)
                ll_g, ll_v = model(x1, x2)

            elif len(batch) == 2:
                feats, labels = batch
                feats  = feats.to(device, dtype=torch.float32)
                labels = labels.to(device)
                # Only unsqueeze if feats is 2D (batch, dim)
                if feats.dim() == 2:
                    feats = feats.unsqueeze(1)
                # else feats.dim()==3: (batch, seq_len, dim) → OK
                ll_g, ll_v = model(feats, feats)

            else:
                raise ValueError(f"Unexpected batch size: {len(batch)}")

            ll_f = torch.where(labels==0, ll_g, ll_v)
            all_ll.extend(ll_f.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    all_ll      = np.array(all_ll)
    all_labels  = np.array(all_labels)

    # pick threshold by best F1
    if threshold is None:
        best_f1, best_thr = 0.0, 0.0
        for thr in np.linspace(all_ll.min(), all_ll.max(), 100):
            preds = (all_ll < thr).astype(int)
            f1 = f1_score(all_labels, preds, zero_division=0)
            if f1 > best_f1:
                best_f1, best_thr = f1, thr
        threshold = best_thr

    preds = (all_ll < threshold).astype(int)

    # compute metrics
    accuracy  = precision_score(all_labels, preds, zero_division=0)  # typo in your code? Should be accuracy_score
    accuracy  = (all_labels == preds).mean()
    precision = precision_score(all_labels, preds, zero_division=0)
    recall    = recall_score(all_labels, preds, zero_division=0)
    auc_roc   = roc_auc_score(all_labels, -all_ll)
    f1_pa     = f1_score(all_labels, preds, zero_division=0)  # or your custom PA

    stats = {
        'accuracy':  accuracy,
        'precision': precision,
        'recall':    recall,
        'auc_roc':   auc_roc,
        'f1_pa':     f1_pa,
        'threshold': threshold
    }

    if window_size is not None and true_ts_labels is not None:
        stats['add'] = compute_add(true_ts_labels, window_size, preds, stride)

    return stats

# %%
def plot_log_likelihoods(model, loader, device, dataset_name="Dataset"):
    import numpy as np
    import pandas as pd
    import matplotlib.pyplot as plt
    import seaborn as sns
    from torch import no_grad

    model.eval()
    log_likelihoods = []
    labels = []

    normal_log_likelihoods = []
    anomaly_log_likelihoods = []

    with no_grad():
        for batch in loader:
            if len(batch) == 5:
                # old approach: (padded_x1, padded_x2, batch_labels, x1_mask, x2_mask)
                padded_x1, padded_x2, batch_labels, x1_mask, x2_mask = batch

                padded_x1 = padded_x1.to(device)
                padded_x2 = padded_x2.to(device)
                batch_labels = batch_labels.to(device)
                x1_mask = x1_mask.to(device)
                x2_mask = x2_mask.to(device)

                # model returns (ll_gaussian, ll_vine)
                ll_gaussian, ll_vine = model(padded_x1, padded_x2, mask1=x1_mask, mask2=x2_mask)

            elif len(batch) == 2:
                # new approach: (features, labels)
                features, batch_labels = batch
                # shape => (batch_size, features) or (batch_size, seq_len, features)
                features = features.to(device, dtype=torch.float32)
                features = features.unsqueeze(1)  # => shape (B,1,features_dim)

                batch_labels = batch_labels.to(device)

                # If your model expects two inputs, we pass the same feature twice
                ll_gaussian, ll_vine = model(features, features)
            else:
                raise ValueError(f"Unexpected number of items in batch: {len(batch)}")

            # Now we have ll_gaussian, ll_vine, and batch_labels
            # Normal => label=0 => use ll_gaussian
            # Anomaly=> label=1 => use ll_vine
            selected_ll = torch.where(batch_labels == 0, ll_gaussian, ll_vine)

            # Convert to CPU/NumPy
            selected_ll_np = selected_ll.cpu().numpy()
            labels_np = batch_labels.cpu().numpy()

            # Separate normal vs. anomaly for debugging
            normal_mask = (labels_np == 0)
            anomaly_mask= (labels_np == 1)

            normal_ll  = selected_ll_np[normal_mask]
            anomaly_ll = selected_ll_np[anomaly_mask]

            if len(normal_ll) > 0:
                normal_log_likelihoods.extend(normal_ll)
            if len(anomaly_ll) > 0:
                anomaly_log_likelihoods.extend(anomaly_ll)

            log_likelihoods.extend(selected_ll_np)
            labels.extend(labels_np)

    log_likelihoods = np.array(log_likelihoods)
    labels = np.array(labels)

    # Build a DataFrame for plotting
    import pandas as pd
    df = pd.DataFrame({
        'Log-Likelihood': log_likelihoods,
        'Label': ['Anomaly' if lb == 1 else 'Normal' for lb in labels]
    })

    # Summary stats
    if len(normal_log_likelihoods) > 0:
        mean_normal = np.mean(normal_log_likelihoods)
    else:
        mean_normal = float('nan')

    if len(anomaly_log_likelihoods) > 0:
        mean_anomaly = np.mean(anomaly_log_likelihoods)
    else:
        mean_anomaly = float('nan')

    print(f"[{dataset_name}] Mean Normal Log-Likelihood: {mean_normal:.4f}")
    print(f"[{dataset_name}] Mean Anomaly Log-Likelihood: {mean_anomaly:.4f}")

    # Plot distributions via Seaborn
    plt.figure(figsize=(10, 6))
    sns.kdeplot(data=df, x='Log-Likelihood', hue='Label', fill=True, common_norm=False, alpha=0.5)
    plt.title(f'Log-Likelihood Distribution for {dataset_name} Set')
    plt.show()

# %%
import numpy as np
import torch
from torch.utils.data import Dataset

class WindowedDataset(Dataset):
    def __init__(self, features, labels, window_size, stride, min_anoms=1, transform=None):
        """
        features:    np.array of shape (T, d)
        labels:      np.array of shape (T,) with 0/1
        window_size: int, length of each frame
        stride:      int, step between frames
        min_anoms:   int, minimum number of 1’s in a window to call it anomalous
        """
        self.transform = transform
        Xw, yw = [], []
        T, d = features.shape

        for start in range(0, T - window_size + 1, stride):
            end = start + window_size
            x_win = features[start:end]      # shape (window_size, d)
            y_win = labels[start:end]        # shape (window_size,)

            # count anomalies in the window
            num_anoms = int(np.sum(y_win))

            # label = 1 only if at least k anomalies present
            label = 1 if num_anoms >= min_anoms else 0

            Xw.append(x_win)
            yw.append(label)

        self.X = np.stack(Xw, axis=0)        # shape (N_windows, window_size, d)
        self.y = np.array(yw, dtype=int)     # shape (N_windows,)

    def __len__(self):
        return len(self.y)

    def __getitem__(self, idx):
        x = self.X[idx]                      # (window_size, d)
        y = self.y[idx]                      # 0 or 1
        if self.transform is not None:
            x = self.transform(x)
        return x, y

# %%
from sklearn.metrics import precision_score, recall_score, f1_score
from sklearn.metrics import roc_auc_score
from torch.optim.lr_scheduler import ReduceLROnPlateau

# %% [markdown]
# **Transformer + Copula**

# %%
# ── D) HYPERPARAMS & DATA ──
num_epochs     =  10
window_lengths = [20, 50, 100, 200]
batch_size     = 64

val_indices = val_subset.indices
val_true_ts = np.array(test_labels[val_indices], dtype=int)


metrics_history = {
    L: {k: [] for k in
        ['accuracy','precision','recall','auc_roc','f1_pa','threshold','add']}
    for L in window_lengths
}

scheduler = ReduceLROnPlateau(optimizer, mode='max',
                              factor=0.5, patience=5, verbose=True)

# ── E) TRAIN/VALIDATE ──
for epoch in range(num_epochs):
    # TRAIN
    model.train()
    total_loss = 0.0
    for x1, x2, y, m1, m2 in train_loader:
        x1, x2, y, m1, m2 = [t.to(device) for t in (x1,x2,y,m1,m2)]
        optimizer.zero_grad()
        ll_g, ll_v = model(x1, x2, mask1=m1, mask2=m2)
        loss = contrastive_loss(ll_g, ll_v, y, alpha=0.3, base_margin=500.)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    print(f"\nEpoch {epoch+1}/{num_epochs} — Loss: {total_loss/len(train_loader):.4f}")

    # VALIDATE each L
    for L in window_lengths:
        # val_ds = WindowedDataset(test_features[val_indices],
        #                          test_labels[val_indices],
        #                          window_size=L, stride=1)

        k = 3
        val_ds = WindowedDataset(
            test_features[val_indices],
            test_labels[val_indices],
            window_size=L,
            stride=1,
            min_anoms=k
        )
        val_loader_L = DataLoader(val_ds,
                                  batch_size=batch_size,
                                  shuffle=False,
                                  num_workers=2)

        stats = validate(model, val_loader_L, device,
                         threshold=None,
                         window_size=L,
                         true_ts_labels=val_true_ts,
                         stride=1)
        for k in metrics_history[L]:
            metrics_history[L][k].append(stats[k])

        print(f" [L={L:3d}] Acc={stats['accuracy']:.3f}  "
              f"Prec={stats['precision']:.3f}  Rec={stats['recall']:.3f}  "
              f"AUC={stats['auc_roc']:.3f}  F1_PA={stats['f1_pa']:.3f}  "
              f"Thr={stats['threshold']:.3f}  ADD={stats['add']:.2f}")

    # scheduler.step(metrics_history[window_lengths[0]]['auc_roc'][-1])

# ── F) PLOTS ──

epochs = np.arange(1, num_epochs+1)
# ADD curves
plt.figure(figsize=(8,5))
for L in window_lengths:
    plt.plot(epochs, metrics_history[L]['add'], marker='o', label=f"L={L}")
plt.xlabel("Epoch"); plt.ylabel("Average Detection Delay"); plt.legend(); plt.show()

# Classification metrics per L
for L in window_lengths:
    plt.figure(figsize=(8,4))
    for m,label,mk in [
        ('accuracy', 'Acc','s'),
        ('precision','Prec','o'),
        ('recall','Rec','^'),
        ('auc_roc','AUC','d')
    ]:
        plt.plot(epochs, metrics_history[L][m],
                 marker=mk, label=label)
    plt.title(f"Metrics vs Epoch (L={L})")
    plt.xlabel("Epoch"); plt.ylabel("Value")
    plt.ylim(0,1)
    plt.legend()
    plt.grid(True)
    plt.show()
# Out:
# Contrastive Loss - Normal LL Mean: -6.9042
# Contrastive Loss - Anomalous LL Mean: 143.4826
# Contrastive Loss - Normal LL Mean: -2.0391
# Contrastive Loss - Anomalous LL Mean: 143.2800
# Contrastive Loss - Normal LL Mean: 7.5712
# Contrastive Loss - Anomalous LL Mean: 146.6532
# Contrastive Loss - Normal LL Mean: 9.3700
# Contrastive Loss - Anomalous LL Mean: 147.3641
# Contrastive Loss - Normal LL Mean: 2.2952
# Contrastive Loss - Anomalous LL Mean: 146.9304
# Contrastive Loss - Normal LL Mean: 8.2261
# Contrastive Loss - Anomalous LL Mean: 148.2038
# Contrastive Loss - Normal LL Mean: 10.7356
# Contrastive Loss - Anomalous LL Mean: 148.3947
# Contrastive Loss - Normal LL Mean: 2.7380
# Contrastive Loss - Anomalous LL Mean: 145.5628
# Contrastive Loss - Normal LL Mean: 4.0486
# Contrastive Loss - Anomalous LL Mean: 145.6589
# Contrastive Loss - Normal LL Mean: 10.8338
# Contrastive Loss - Anomalous LL Mean: 146.8605
# Contrastive Loss - Normal LL Mean: 7.4958
# Contrastive Loss - Anomalous LL Mean: 147.7485
# Contrastive Loss - Normal LL Mean: 18.9242
# Contrastive Loss - Anomalous LL Mean: 150.6704
# Contrastive Loss - Normal LL Mean: 2.9232
# Contrastive Loss - Anomalous LL Mean: 144.6567
# Contrastive Loss - Normal LL Mean: 2.2804
# Contrastive Loss - Anomalous LL Mean: 144.8386
# Contrastive Loss - Normal LL Mean: 4.5949
# Contrastive Loss - Anomalous LL Mean: 146.2425
# Contrastive Loss - Normal LL Mean: 0.1026
# Contrastive Loss - Anomalous LL Mean: 143.9941
# Contrastive Loss - Normal LL Mean: 3.9645
# Contrastive Loss - Anomalous LL Mean: 145.0630
# Contrastive Loss - Normal LL Mean: 5.1819
# Contrastive Loss - Anomalous LL Mean: 145.5920
# Contrastive Loss - Normal LL Mean: 5.1854
# Contrastive Loss - Anomalous LL Mean: 146.0256
# Contrastive Loss - Normal LL Mean: -0.5104
# Contrastive Loss - Anomalous LL Mean: 144.4784
# Contrastive Loss - Normal LL Mean: -2.4242
# Contrastive Loss - Anomalous LL Mean: 143.9674
# Contrastive Loss - Normal LL Mean: -0.4791
# Contrastive Loss - Anomalous LL Mean: 143.6009
# Contrastive Loss - Normal LL Mean: -10.5544
# Contrastive Loss - Anomalous LL Mean: 141.2601
# Contrastive Loss - Normal LL Mean: 6.0700
# Contrastive Loss - Anomalous LL Mean: 146.1548
# Contrastive Loss - Normal LL Mean: -3.0932
# Contrastive Loss - Anomalous LL Mean: 143.7483
# Contrastive Loss - Normal LL Mean: 2.0681
# Contrastive Loss - Anomalous LL Mean: 144.4682
# Contrastive Loss - Normal LL Mean: 5.8427
# Contrastive Loss - Anomalous LL Mean: 145.4506
# Contrastive Loss - Normal LL Mean: -2.8875
# Contrastive Loss - Anomalous LL Mean: 142.3212
# Contrastive Loss - Normal LL Mean: 0.4140
# Contrastive Loss - Anomalous LL Mean: 144.4036
# Contrastive Loss - Normal LL Mean: 20.9123
# Contrastive Loss - Anomalous LL Mean: 149.3403
#
# Epoch 1/10 — Loss: 148.1812
#  [L= 20] Acc=0.940  Prec=0.475  Rec=0.250  AUC=0.680  F1_PA=0.328  Thr=-28.155  ADD=15.67
#  [L= 50] Acc=0.938  Prec=0.488  Rec=0.255  AUC=0.733  F1_PA=0.335  Thr=-27.989  ADD=37.83
#  [L=100] Acc=0.929  Prec=0.447  Rec=0.280  AUC=0.733  F1_PA=0.344  Thr=-26.741  ADD=17.67
#  [L=200] Acc=0.916  Prec=0.426  Rec=0.283  AUC=0.678  F1_PA=0.340  Thr=-25.742  ADD=13.50
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Contrastive Loss - Normal LL Mean: -4.4844
# Contrastive Loss - Anomalous LL Mean: 142.6061
# Contrastive Loss - Normal LL Mean: 4.5969
# Contrastive Loss - Anomalous LL Mean: 145.2115
# Contrastive Loss - Normal LL Mean: 0.3944
# Contrastive Loss - Anomalous LL Mean: 143.8360
# Contrastive Loss - Normal LL Mean: -2.6107
# Contrastive Loss - Anomalous LL Mean: 142.1125
# Contrastive Loss - Normal LL Mean: 11.8371
# Contrastive Loss - Anomalous LL Mean: 146.6906
# Contrastive Loss - Normal LL Mean: 3.8844
# Contrastive Loss - Anomalous LL Mean: 144.9385
# Contrastive Loss - Normal LL Mean: -7.9982
# Contrastive Loss - Anomalous LL Mean: 140.7236
# Contrastive Loss - Normal LL Mean: 5.4815
# Contrastive Loss - Anomalous LL Mean: 144.7003
# Contrastive Loss - Normal LL Mean: 8.2283
# Contrastive Loss - Anomalous LL Mean: 145.7018
# Contrastive Loss - Normal LL Mean: 3.8628
# Contrastive Loss - Anomalous LL Mean: 144.5941
# Contrastive Loss - Normal LL Mean: 6.2477
# Contrastive Loss - Anomalous LL Mean: 145.0546
# Contrastive Loss - Normal LL Mean: 1.5959
# Contrastive Loss - Anomalous LL Mean: 144.9142
# Contrastive Loss - Normal LL Mean: 9.1475
# Contrastive Loss - Anomalous LL Mean: 144.6295
# Contrastive Loss - Normal LL Mean: 0.7835
# Contrastive Loss - Anomalous LL Mean: 143.3261
# Contrastive Loss - Normal LL Mean: 6.3758
# Contrastive Loss - Anomalous LL Mean: 144.8193
# Contrastive Loss - Normal LL Mean: 1.9287
# Contrastive Loss - Anomalous LL Mean: 144.1806
# Contrastive Loss - Normal LL Mean: -9.9065
# Contrastive Loss - Anomalous LL Mean: 139.9282
# Contrastive Loss - Normal LL Mean: 4.6521
# Contrastive Loss - Anomalous LL Mean: 144.2642
# Contrastive Loss - Normal LL Mean: 3.4410
# Contrastive Loss - Anomalous LL Mean: 143.1260
# Contrastive Loss - Normal LL Mean: -0.5412
# Contrastive Loss - Anomalous LL Mean: 142.4077
# Contrastive Loss - Normal LL Mean: -0.4663
# Contrastive Loss - Anomalous LL Mean: 142.3095
# Contrastive Loss - Normal LL Mean: 15.5793
# Contrastive Loss - Anomalous LL Mean: 146.8094
# Contrastive Loss - Normal LL Mean: 3.5276
# Contrastive Loss - Anomalous LL Mean: 143.8793
# Contrastive Loss - Normal LL Mean: -3.5273
# Contrastive Loss - Anomalous LL Mean: 141.5262
# Contrastive Loss - Normal LL Mean: -0.1495
# Contrastive Loss - Anomalous LL Mean: 141.5754
# Contrastive Loss - Normal LL Mean: -0.7214
# Contrastive Loss - Anomalous LL Mean: 142.4603
# Contrastive Loss - Normal LL Mean: -6.9430
# Contrastive Loss - Anomalous LL Mean: 139.2958
# Contrastive Loss - Normal LL Mean: 19.9616
# Contrastive Loss - Anomalous LL Mean: 149.4970
# Contrastive Loss - Normal LL Mean: 6.4166
# Contrastive Loss - Anomalous LL Mean: 143.7317
# Contrastive Loss - Normal LL Mean: -13.4415
# Contrastive Loss - Anomalous LL Mean: 139.5978
#
# Epoch 2/10 — Loss: 145.1818
#  [L= 20] Acc=0.951  Prec=0.635  Rec=0.348  AUC=0.742  F1_PA=0.450  Thr=-27.563  ADD=3.50
#  [L= 50] Acc=0.950  Prec=0.678  Rec=0.359  AUC=0.796  F1_PA=0.469  Thr=-27.826  ADD=34.83
#  [L=100] Acc=0.942  Prec=0.606  Rec=0.390  AUC=0.799  F1_PA=0.475  Thr=-26.214  ADD=13.50
#  [L=200] Acc=0.938  Prec=0.698  Rec=0.348  AUC=0.744  F1_PA=0.464  Thr=-27.419  ADD=13.50
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Contrastive Loss - Normal LL Mean: 4.9667
# Contrastive Loss - Anomalous LL Mean: 142.8550
# Contrastive Loss - Normal LL Mean: 7.0148
# Contrastive Loss - Anomalous LL Mean: 143.5052
# Contrastive Loss - Normal LL Mean: 6.5967
# Contrastive Loss - Anomalous LL Mean: 143.7819
# Contrastive Loss - Normal LL Mean: -11.6351
# Contrastive Loss - Anomalous LL Mean: 138.8610
# Contrastive Loss - Normal LL Mean: -8.6713
# Contrastive Loss - Anomalous LL Mean: 141.0873
# Contrastive Loss - Normal LL Mean: -7.1832
# Contrastive Loss - Anomalous LL Mean: 138.7432
# Contrastive Loss - Normal LL Mean: -1.3931
# Contrastive Loss - Anomalous LL Mean: 140.9232
# Contrastive Loss - Normal LL Mean: -5.7277
# Contrastive Loss - Anomalous LL Mean: 138.2592
# Contrastive Loss - Normal LL Mean: -3.0995
# Contrastive Loss - Anomalous LL Mean: 139.9054
# Contrastive Loss - Normal LL Mean: -3.5367
# Contrastive Loss - Anomalous LL Mean: 140.4006
# Contrastive Loss - Normal LL Mean: 3.6463
# Contrastive Loss - Anomalous LL Mean: 141.7506
# Contrastive Loss - Normal LL Mean: 3.5376
# Contrastive Loss - Anomalous LL Mean: 142.0593
# Contrastive Loss - Normal LL Mean: 1.2063
# Contrastive Loss - Anomalous LL Mean: 140.4973
# Contrastive Loss - No Normal Samples in Batch.
# Contrastive Loss - Anomalous LL Mean: 140.9615
# Contrastive Loss - Normal LL Mean: 1.0733
# Contrastive Loss - Anomalous LL Mean: 140.6386
# Contrastive Loss - Normal LL Mean: 8.1790
# Contrastive Loss - Anomalous LL Mean: 142.7153
# Contrastive Loss - Normal LL Mean: -5.3645
# Contrastive Loss - Anomalous LL Mean: 138.4253
# Contrastive Loss - Normal LL Mean: -4.2018
# Contrastive Loss - Anomalous LL Mean: 138.3854
# Contrastive Loss - Normal LL Mean: -10.6580
# Contrastive Loss - Anomalous LL Mean: 137.6949
# Contrastive Loss - Normal LL Mean: 9.6668
# Contrastive Loss - Anomalous LL Mean: 143.7604
# Contrastive Loss - Normal LL Mean: -5.9599
# Contrastive Loss - Anomalous LL Mean: 139.0942
# Contrastive Loss - Normal LL Mean: -5.8776
# Contrastive Loss - Anomalous LL Mean: 139.1076
# Contrastive Loss - Normal LL Mean: 0.2436
# Contrastive Loss - Anomalous LL Mean: 139.9668
# Contrastive Loss - Normal LL Mean: -0.0966
# Contrastive Loss - Anomalous LL Mean: 141.2702
# Contrastive Loss - Normal LL Mean: -1.2294
# Contrastive Loss - Anomalous LL Mean: 139.9507
# Contrastive Loss - Normal LL Mean: -3.7965
# Contrastive Loss - Anomalous LL Mean: 139.7863
# Contrastive Loss - Normal LL Mean: 10.3452
# Contrastive Loss - Anomalous LL Mean: 144.7479
# Contrastive Loss - Normal LL Mean: 3.4660
# Contrastive Loss - Anomalous LL Mean: 139.4510
# Contrastive Loss - Normal LL Mean: 4.2539
# Contrastive Loss - Anomalous LL Mean: 141.7673
# Contrastive Loss - Normal LL Mean: -0.3615
# Contrastive Loss - Anomalous LL Mean: 140.8148
#
# Epoch 3/10 — Loss: 140.3650
#  [L= 20] Acc=0.961  Prec=0.780  Rec=0.457  AUC=0.796  F1_PA=0.576  Thr=-27.511  ADD=3.33
#  [L= 50] Acc=0.957  Prec=0.711  Rec=0.497  AUC=0.847  F1_PA=0.585  Thr=-25.857  ADD=18.17
#  [L=100] Acc=0.957  Prec=0.801  Rec=0.480  AUC=0.855  F1_PA=0.600  Thr=-27.082  ADD=9.50
#  [L=200] Acc=0.948  Prec=0.764  Rec=0.475  AUC=0.802  F1_PA=0.585  Thr=-26.026  ADD=8.83
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Contrastive Loss - Normal LL Mean: -2.3339
# Contrastive Loss - Anomalous LL Mean: 138.1753
# Contrastive Loss - Normal LL Mean: -6.8697
# Contrastive Loss - Anomalous LL Mean: 137.7164
# Contrastive Loss - Normal LL Mean: 2.3343
# Contrastive Loss - Anomalous LL Mean: 139.8760
# Contrastive Loss - Normal LL Mean: 3.3880
# Contrastive Loss - Anomalous LL Mean: 140.0543
# Contrastive Loss - Normal LL Mean: -2.8384
# Contrastive Loss - Anomalous LL Mean: 140.2888
# Contrastive Loss - Normal LL Mean: -4.8973
# Contrastive Loss - Anomalous LL Mean: 138.9870
# Contrastive Loss - Normal LL Mean: -1.9329
# Contrastive Loss - Anomalous LL Mean: 138.6775
# Contrastive Loss - Normal LL Mean: -6.2070
# Contrastive Loss - Anomalous LL Mean: 137.4756
# Contrastive Loss - Normal LL Mean: 2.2817
# Contrastive Loss - Anomalous LL Mean: 138.9949
# Contrastive Loss - Normal LL Mean: -1.4412
# Contrastive Loss - Anomalous LL Mean: 137.8177
# Contrastive Loss - Normal LL Mean: 3.5725
# Contrastive Loss - Anomalous LL Mean: 138.9768
# Contrastive Loss - Normal LL Mean: -2.2670
# Contrastive Loss - Anomalous LL Mean: 138.1672
# Contrastive Loss - Normal LL Mean: 6.7067
# Contrastive Loss - Anomalous LL Mean: 141.3232
# Contrastive Loss - Normal LL Mean: 6.0241
# Contrastive Loss - Anomalous LL Mean: 141.1778
# Contrastive Loss - Normal LL Mean: 0.3376
# Contrastive Loss - Anomalous LL Mean: 137.8665
# Contrastive Loss - Normal LL Mean: -7.3515
# Contrastive Loss - Anomalous LL Mean: 136.2565
# Contrastive Loss - Normal LL Mean: 3.2210
# Contrastive Loss - Anomalous LL Mean: 139.8562
# Contrastive Loss - Normal LL Mean: 2.0456
# Contrastive Loss - Anomalous LL Mean: 138.9200
# Contrastive Loss - Normal LL Mean: -8.6205
# Contrastive Loss - Anomalous LL Mean: 135.3791
# Contrastive Loss - Normal LL Mean: -0.3232
# Contrastive Loss - Anomalous LL Mean: 137.7360
# Contrastive Loss - Normal LL Mean: 3.8597
# Contrastive Loss - Anomalous LL Mean: 140.1480
# Contrastive Loss - Normal LL Mean: -2.9251
# Contrastive Loss - Anomalous LL Mean: 138.7913
# Contrastive Loss - Normal LL Mean: -6.4356
# Contrastive Loss - Anomalous LL Mean: 135.3622
# Contrastive Loss - Normal LL Mean: -3.6527
# Contrastive Loss - Anomalous LL Mean: 135.3773
# Contrastive Loss - Normal LL Mean: 1.3854
# Contrastive Loss - Anomalous LL Mean: 137.5235
# Contrastive Loss - Normal LL Mean: 0.4318
# Contrastive Loss - Anomalous LL Mean: 138.9258
# Contrastive Loss - Normal LL Mean: -20.3819
# Contrastive Loss - Anomalous LL Mean: 130.3490
# Contrastive Loss - Normal LL Mean: -18.3620
# Contrastive Loss - Anomalous LL Mean: 131.1323
# Contrastive Loss - Normal LL Mean: 7.2282
# Contrastive Loss - Anomalous LL Mean: 141.7261
# Contrastive Loss - Normal LL Mean: -7.3150
# Contrastive Loss - Anomalous LL Mean: 134.1313
#
# Epoch 4/10 — Loss: 136.4751
#  [L= 20] Acc=0.971  Prec=0.922  Rec=0.540  AUC=0.845  F1_PA=0.681  Thr=-28.588  ADD=3.00
#  [L= 50] Acc=0.969  Prec=0.852  Rec=0.607  AUC=0.886  F1_PA=0.709  Thr=-26.396  ADD=15.00
#  [L=100] Acc=0.967  Prec=0.861  Rec=0.611  AUC=0.898  F1_PA=0.714  Thr=-26.286  ADD=4.83
#  [L=200] Acc=0.961  Prec=0.887  Rec=0.560  AUC=0.852  F1_PA=0.686  Thr=-27.053  ADD=8.67
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Contrastive Loss - Normal LL Mean: 4.0519
# Contrastive Loss - Anomalous LL Mean: 137.5468
# Contrastive Loss - Normal LL Mean: -3.5928
# Contrastive Loss - Anomalous LL Mean: 134.9333
# Contrastive Loss - Normal LL Mean: -5.2464
# Contrastive Loss - Anomalous LL Mean: 135.0377
# Contrastive Loss - Normal LL Mean: -1.9640
# Contrastive Loss - Anomalous LL Mean: 137.3359
# Contrastive Loss - Normal LL Mean: 7.5045
# Contrastive Loss - Anomalous LL Mean: 139.1402
# Contrastive Loss - Normal LL Mean: 5.1380
# Contrastive Loss - Anomalous LL Mean: 138.9080
# Contrastive Loss - Normal LL Mean: -2.2425
# Contrastive Loss - Anomalous LL Mean: 134.0726
# Contrastive Loss - Normal LL Mean: 4.0995
# Contrastive Loss - Anomalous LL Mean: 138.5672
# Contrastive Loss - Normal LL Mean: -2.9892
# Contrastive Loss - Anomalous LL Mean: 136.1315
# Contrastive Loss - Normal LL Mean: -4.3243
# Contrastive Loss - Anomalous LL Mean: 136.3887
# Contrastive Loss - Normal LL Mean: -3.3365
# Contrastive Loss - Anomalous LL Mean: 134.4683
# Contrastive Loss - Normal LL Mean: -2.0988
# Contrastive Loss - Anomalous LL Mean: 135.2810
# Contrastive Loss - Normal LL Mean: -0.9918
# Contrastive Loss - Anomalous LL Mean: 135.3455
# Contrastive Loss - Normal LL Mean: -11.2751
# Contrastive Loss - Anomalous LL Mean: 131.9943
# Contrastive Loss - Normal LL Mean: -7.5792
# Contrastive Loss - Anomalous LL Mean: 133.4767
# Contrastive Loss - Normal LL Mean: -2.3017
# Contrastive Loss - Anomalous LL Mean: 134.0397
# Contrastive Loss - Normal LL Mean: -8.4665
# Contrastive Loss - Anomalous LL Mean: 132.9463
# Contrastive Loss - Normal LL Mean: -1.9745
# Contrastive Loss - Anomalous LL Mean: 134.0774
# Contrastive Loss - Normal LL Mean: 5.0847
# Contrastive Loss - Anomalous LL Mean: 136.7051
# Contrastive Loss - Normal LL Mean: -13.8797
# Contrastive Loss - Anomalous LL Mean: 130.9492
# Contrastive Loss - Normal LL Mean: 1.2444
# Contrastive Loss - Anomalous LL Mean: 134.2195
# Contrastive Loss - Normal LL Mean: -10.6279
# Contrastive Loss - Anomalous LL Mean: 131.4762
# Contrastive Loss - Normal LL Mean: -7.2063
# Contrastive Loss - Anomalous LL Mean: 132.3086
# Contrastive Loss - Normal LL Mean: 1.5097
# Contrastive Loss - Anomalous LL Mean: 135.3961
# Contrastive Loss - Normal LL Mean: -4.7620
# Contrastive Loss - Anomalous LL Mean: 130.9598
# Contrastive Loss - Normal LL Mean: 4.6240
# Contrastive Loss - Anomalous LL Mean: 134.8690
# Contrastive Loss - Normal LL Mean: -4.9267
# Contrastive Loss - Anomalous LL Mean: 133.4924
# Contrastive Loss - Normal LL Mean: -4.3985
# Contrastive Loss - Anomalous LL Mean: 132.9951
# Contrastive Loss - Normal LL Mean: -12.6229
# Contrastive Loss - Anomalous LL Mean: 131.3251
# Contrastive Loss - Normal LL Mean: -1.1103
# Contrastive Loss - Anomalous LL Mean: 131.1872
#
# Epoch 5/10 — Loss: 132.5437
#  [L= 20] Acc=0.977  Prec=0.934  Rec=0.646  AUC=0.889  F1_PA=0.764  Thr=-27.390  ADD=2.67
#  [L= 50] Acc=0.978  Prec=0.917  Rec=0.699  AUC=0.917  F1_PA=0.793  Thr=-26.614  ADD=8.17
#  [L=100] Acc=0.977  Prec=0.936  Rec=0.696  AUC=0.930  F1_PA=0.799  Thr=-27.021  ADD=4.33
#  [L=200] Acc=0.970  Prec=0.948  Rec=0.648  AUC=0.895  F1_PA=0.770  Thr=-27.651  ADD=2.50
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Contrastive Loss - Normal LL Mean: -13.7731
# Contrastive Loss - Anomalous LL Mean: 129.7894
# Contrastive Loss - Normal LL Mean: -11.2994
# Contrastive Loss - Anomalous LL Mean: 130.1502
# Contrastive Loss - Normal LL Mean: -4.5039
# Contrastive Loss - Anomalous LL Mean: 131.8849
# Contrastive Loss - Normal LL Mean: -12.1478
# Contrastive Loss - Anomalous LL Mean: 128.3740
# Contrastive Loss - Normal LL Mean: 3.5156
# Contrastive Loss - Anomalous LL Mean: 132.2974
# Contrastive Loss - Normal LL Mean: -11.9100
# Contrastive Loss - Anomalous LL Mean: 131.2665
# Contrastive Loss - Normal LL Mean: 2.4779
# Contrastive Loss - Anomalous LL Mean: 134.9819
# Contrastive Loss - Normal LL Mean: -5.6041
# Contrastive Loss - Anomalous LL Mean: 130.6885
# Contrastive Loss - Normal LL Mean: -4.7981
# Contrastive Loss - Anomalous LL Mean: 129.5560
# Contrastive Loss - Normal LL Mean: 6.9623
# Contrastive Loss - Anomalous LL Mean: 132.4078
# Contrastive Loss - Normal LL Mean: -3.0787
# Contrastive Loss - Anomalous LL Mean: 132.2210
# Contrastive Loss - Normal LL Mean: -3.4890
# Contrastive Loss - Anomalous LL Mean: 129.4335
# Contrastive Loss - Normal LL Mean: -3.3658
# Contrastive Loss - Anomalous LL Mean: 130.6681
# Contrastive Loss - Normal LL Mean: 1.8224
# Contrastive Loss - Anomalous LL Mean: 134.0994
# Contrastive Loss - Normal LL Mean: -13.1092
# Contrastive Loss - Anomalous LL Mean: 127.4315
# Contrastive Loss - Normal LL Mean: -5.6799
# Contrastive Loss - Anomalous LL Mean: 128.8811
# Contrastive Loss - Normal LL Mean: -7.6026
# Contrastive Loss - Anomalous LL Mean: 131.1832
# Contrastive Loss - Normal LL Mean: 0.8719
# Contrastive Loss - Anomalous LL Mean: 130.4479
# Contrastive Loss - Normal LL Mean: 3.8782
# Contrastive Loss - Anomalous LL Mean: 133.4548
# Contrastive Loss - Normal LL Mean: -3.3113
# Contrastive Loss - Anomalous LL Mean: 129.1111
# Contrastive Loss - Normal LL Mean: -9.7603
# Contrastive Loss - Anomalous LL Mean: 127.4593
# Contrastive Loss - Normal LL Mean: -3.2299
# Contrastive Loss - Anomalous LL Mean: 130.3373
# Contrastive Loss - Normal LL Mean: -5.2977
# Contrastive Loss - Anomalous LL Mean: 128.8179
# Contrastive Loss - Normal LL Mean: -4.1171
# Contrastive Loss - Anomalous LL Mean: 129.3092
# Contrastive Loss - Normal LL Mean: -6.6420
# Contrastive Loss - Anomalous LL Mean: 129.9517
# Contrastive Loss - Normal LL Mean: -4.4560
# Contrastive Loss - Anomalous LL Mean: 130.3264
# Contrastive Loss - Normal LL Mean: -12.6129
# Contrastive Loss - Anomalous LL Mean: 123.5776
# Contrastive Loss - Normal LL Mean: -8.8125
# Contrastive Loss - Anomalous LL Mean: 128.3612
# Contrastive Loss - Normal LL Mean: 2.3218
# Contrastive Loss - Anomalous LL Mean: 132.1916
# Contrastive Loss - Normal LL Mean: -2.3409
# Contrastive Loss - Anomalous LL Mean: 128.1868
#
# Epoch 6/10 — Loss: 126.9828
#  [L= 20] Acc=0.982  Prec=0.952  Rec=0.733  AUC=0.926  F1_PA=0.828  Thr=-26.952  ADD=2.33
#  [L= 50] Acc=0.983  Prec=0.962  Rec=0.760  AUC=0.941  F1_PA=0.849  Thr=-28.000  ADD=6.83
#  [L=100] Acc=0.984  Prec=0.966  Rec=0.786  AUC=0.954  F1_PA=0.867  Thr=-27.231  ADD=3.83
#  [L=200] Acc=0.977  Prec=0.965  Rec=0.729  AUC=0.929  F1_PA=0.830  Thr=-27.243  ADD=2.33
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Contrastive Loss - Normal LL Mean: -12.3354
# Contrastive Loss - Anomalous LL Mean: 126.4523
# Contrastive Loss - Normal LL Mean: 3.9069
# Contrastive Loss - Anomalous LL Mean: 129.9455
# Contrastive Loss - Normal LL Mean: -2.5559
# Contrastive Loss - Anomalous LL Mean: 130.1320
# Contrastive Loss - Normal LL Mean: 13.2275
# Contrastive Loss - Anomalous LL Mean: 133.8285
# Contrastive Loss - Normal LL Mean: -6.6380
# Contrastive Loss - Anomalous LL Mean: 127.0932
# Contrastive Loss - Normal LL Mean: -8.1135
# Contrastive Loss - Anomalous LL Mean: 126.1863
# Contrastive Loss - Normal LL Mean: -1.5179
# Contrastive Loss - Anomalous LL Mean: 130.6585
# Contrastive Loss - Normal LL Mean: 0.4468
# Contrastive Loss - Anomalous LL Mean: 129.0522
# Contrastive Loss - Normal LL Mean: -1.1753
# Contrastive Loss - Anomalous LL Mean: 128.3386
# Contrastive Loss - Normal LL Mean: -11.2118
# Contrastive Loss - Anomalous LL Mean: 125.9440
# Contrastive Loss - Normal LL Mean: -12.5076
# Contrastive Loss - Anomalous LL Mean: 124.1674
# Contrastive Loss - Normal LL Mean: -6.5781
# Contrastive Loss - Anomalous LL Mean: 125.5431
# Contrastive Loss - Normal LL Mean: -14.1246
# Contrastive Loss - Anomalous LL Mean: 122.8208
# Contrastive Loss - Normal LL Mean: -5.5169
# Contrastive Loss - Anomalous LL Mean: 126.9029
# Contrastive Loss - Normal LL Mean: -13.8595
# Contrastive Loss - Anomalous LL Mean: 122.1298
# Contrastive Loss - Normal LL Mean: -3.4700
# Contrastive Loss - Anomalous LL Mean: 124.8116
# Contrastive Loss - Normal LL Mean: -7.5838
# Contrastive Loss - Anomalous LL Mean: 122.4066
# Contrastive Loss - Normal LL Mean: 0.9596
# Contrastive Loss - Anomalous LL Mean: 127.2700
# Contrastive Loss - Normal LL Mean: -5.3905
# Contrastive Loss - Anomalous LL Mean: 122.2249
# Contrastive Loss - Normal LL Mean: -16.4298
# Contrastive Loss - Anomalous LL Mean: 121.3572
# Contrastive Loss - Normal LL Mean: 10.1184
# Contrastive Loss - Anomalous LL Mean: 128.1675
# Contrastive Loss - Normal LL Mean: -2.4109
# Contrastive Loss - Anomalous LL Mean: 124.3478
# Contrastive Loss - Normal LL Mean: -2.6594
# Contrastive Loss - Anomalous LL Mean: 125.2050
# Contrastive Loss - Normal LL Mean: -10.8591
# Contrastive Loss - Anomalous LL Mean: 123.7416
# Contrastive Loss - Normal LL Mean: -6.2588
# Contrastive Loss - Anomalous LL Mean: 127.6340
# Contrastive Loss - Normal LL Mean: -5.4688
# Contrastive Loss - Anomalous LL Mean: 127.3980
# Contrastive Loss - Normal LL Mean: -3.0315
# Contrastive Loss - Anomalous LL Mean: 125.1090
# Contrastive Loss - Normal LL Mean: -5.8332
# Contrastive Loss - Anomalous LL Mean: 122.2889
# Contrastive Loss - Normal LL Mean: -11.0337
# Contrastive Loss - Anomalous LL Mean: 122.2961
# Contrastive Loss - Normal LL Mean: 4.5716
# Contrastive Loss - Anomalous LL Mean: 127.8707
#
# Epoch 7/10 — Loss: 122.6997
#  [L= 20] Acc=0.989  Prec=0.980  Rec=0.821  AUC=0.950  F1_PA=0.893  Thr=-27.501  ADD=2.00
#  [L= 50] Acc=0.987  Prec=0.955  Rec=0.836  AUC=0.960  F1_PA=0.892  Thr=-26.038  ADD=1.50
#  [L=100] Acc=0.988  Prec=0.966  Rec=0.848  AUC=0.969  F1_PA=0.903  Thr=-26.127  ADD=3.33
#  [L=200] Acc=0.983  Prec=0.981  Rec=0.798  AUC=0.952  F1_PA=0.880  Thr=-27.709  ADD=2.17
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Contrastive Loss - Normal LL Mean: -1.6039
# Contrastive Loss - Anomalous LL Mean: 125.1165
# Contrastive Loss - Normal LL Mean: -5.0454
# Contrastive Loss - Anomalous LL Mean: 121.4286
# Contrastive Loss - Normal LL Mean: -7.6422
# Contrastive Loss - Anomalous LL Mean: 119.7305
# Contrastive Loss - Normal LL Mean: -10.4322
# Contrastive Loss - Anomalous LL Mean: 122.1797
# Contrastive Loss - Normal LL Mean: -5.0188
# Contrastive Loss - Anomalous LL Mean: 121.5729
# Contrastive Loss - Normal LL Mean: -7.8574
# Contrastive Loss - Anomalous LL Mean: 123.0782
# Contrastive Loss - Normal LL Mean: -11.4090
# Contrastive Loss - Anomalous LL Mean: 117.2490
# Contrastive Loss - Normal LL Mean: 23.0038
# Contrastive Loss - Anomalous LL Mean: 129.5539
# Contrastive Loss - Normal LL Mean: -6.1927
# Contrastive Loss - Anomalous LL Mean: 124.2548
# Contrastive Loss - Normal LL Mean: -11.6347
# Contrastive Loss - Anomalous LL Mean: 121.6235
# Contrastive Loss - Normal LL Mean: -3.5581
# Contrastive Loss - Anomalous LL Mean: 123.9877
# Contrastive Loss - Normal LL Mean: 1.2928
# Contrastive Loss - Anomalous LL Mean: 123.6760
# Contrastive Loss - Normal LL Mean: -6.5719
# Contrastive Loss - Anomalous LL Mean: 120.6482
# Contrastive Loss - Normal LL Mean: -3.8136
# Contrastive Loss - Anomalous LL Mean: 120.6058
# Contrastive Loss - Normal LL Mean: -2.9752
# Contrastive Loss - Anomalous LL Mean: 121.7445
# Contrastive Loss - Normal LL Mean: -6.2836
# Contrastive Loss - Anomalous LL Mean: 121.9104
# Contrastive Loss - Normal LL Mean: 9.9462
# Contrastive Loss - Anomalous LL Mean: 124.7402
# Contrastive Loss - Normal LL Mean: 2.5761
# Contrastive Loss - Anomalous LL Mean: 123.3700
# Contrastive Loss - Normal LL Mean: -9.1453
# Contrastive Loss - Anomalous LL Mean: 119.0497
# Contrastive Loss - Normal LL Mean: -9.6261
# Contrastive Loss - Anomalous LL Mean: 122.9546
# Contrastive Loss - Normal LL Mean: -14.1477
# Contrastive Loss - Anomalous LL Mean: 116.4401
# Contrastive Loss - Normal LL Mean: 4.9702
# Contrastive Loss - Anomalous LL Mean: 125.1604
# Contrastive Loss - Normal LL Mean: 2.4894
# Contrastive Loss - Anomalous LL Mean: 122.2513
# Contrastive Loss - Normal LL Mean: -7.8008
# Contrastive Loss - Anomalous LL Mean: 118.8868
# Contrastive Loss - Normal LL Mean: -10.9573
# Contrastive Loss - Anomalous LL Mean: 119.1764
# Contrastive Loss - Normal LL Mean: -2.7527
# Contrastive Loss - Anomalous LL Mean: 121.2344
# Contrastive Loss - Normal LL Mean: -0.6205
# Contrastive Loss - Anomalous LL Mean: 121.6469
# Contrastive Loss - Normal LL Mean: 3.1971
# Contrastive Loss - Anomalous LL Mean: 120.4820
# Contrastive Loss - Normal LL Mean: 1.4827
# Contrastive Loss - Anomalous LL Mean: 121.0124
# Contrastive Loss - Normal LL Mean: -4.7400
# Contrastive Loss - Anomalous LL Mean: 117.1908
#
# Epoch 8/10 — Loss: 119.3782
#  [L= 20] Acc=0.992  Prec=0.986  Rec=0.882  AUC=0.966  F1_PA=0.931  Thr=-26.923  ADD=2.00
#  [L= 50] Acc=0.991  Prec=0.981  Rec=0.876  AUC=0.973  F1_PA=0.925  Thr=-27.528  ADD=1.50
#  [L=100] Acc=0.992  Prec=0.977  Rec=0.899  AUC=0.979  F1_PA=0.936  Thr=-25.907  ADD=3.17
#  [L=200] Acc=0.988  Prec=0.985  Rec=0.859  AUC=0.967  F1_PA=0.918  Thr=-26.989  ADD=1.83
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Contrastive Loss - Normal LL Mean: 1.2720
# Contrastive Loss - Anomalous LL Mean: 119.1250
# Contrastive Loss - Normal LL Mean: -6.7934
# Contrastive Loss - Anomalous LL Mean: 121.2874
# Contrastive Loss - Normal LL Mean: 0.4164
# Contrastive Loss - Anomalous LL Mean: 120.6882
# Contrastive Loss - Normal LL Mean: -11.9832
# Contrastive Loss - Anomalous LL Mean: 117.5407
# Contrastive Loss - Normal LL Mean: -1.6210
# Contrastive Loss - Anomalous LL Mean: 119.7995
# Contrastive Loss - Normal LL Mean: -2.4527
# Contrastive Loss - Anomalous LL Mean: 117.7166
# Contrastive Loss - Normal LL Mean: 14.0242
# Contrastive Loss - Anomalous LL Mean: 124.7529
# Contrastive Loss - Normal LL Mean: -19.7488
# Contrastive Loss - Anomalous LL Mean: 111.7499
# Contrastive Loss - Normal LL Mean: -5.5124
# Contrastive Loss - Anomalous LL Mean: 117.0831
# Contrastive Loss - Normal LL Mean: -9.3422
# Contrastive Loss - Anomalous LL Mean: 115.1160
# Contrastive Loss - Normal LL Mean: -8.2353
# Contrastive Loss - Anomalous LL Mean: 115.4235
# Contrastive Loss - Normal LL Mean: -3.4195
# Contrastive Loss - Anomalous LL Mean: 115.3044
# Contrastive Loss - Normal LL Mean: -0.8852
# Contrastive Loss - Anomalous LL Mean: 122.3330
# Contrastive Loss - Normal LL Mean: -14.4028
# Contrastive Loss - Anomalous LL Mean: 111.6974
# Contrastive Loss - Normal LL Mean: 6.3726
# Contrastive Loss - Anomalous LL Mean: 119.8219
# Contrastive Loss - Normal LL Mean: 0.6968
# Contrastive Loss - Anomalous LL Mean: 114.9210
# Contrastive Loss - Normal LL Mean: -10.1159
# Contrastive Loss - Anomalous LL Mean: 110.1758
# Contrastive Loss - Normal LL Mean: -6.9198
# Contrastive Loss - Anomalous LL Mean: 110.6428
# Contrastive Loss - Normal LL Mean: -23.0746
# Contrastive Loss - Anomalous LL Mean: 109.2145
# Contrastive Loss - Normal LL Mean: -3.9531
# Contrastive Loss - Anomalous LL Mean: 119.7559
# Contrastive Loss - Normal LL Mean: -9.0002
# Contrastive Loss - Anomalous LL Mean: 110.5636
# Contrastive Loss - Normal LL Mean: -0.0262
# Contrastive Loss - Anomalous LL Mean: 112.1286
# Contrastive Loss - Normal LL Mean: -11.7082
# Contrastive Loss - Anomalous LL Mean: 110.5257
# Contrastive Loss - Normal LL Mean: -12.0077
# Contrastive Loss - Anomalous LL Mean: 112.7041
# Contrastive Loss - Normal LL Mean: -10.3591
# Contrastive Loss - Anomalous LL Mean: 113.5694
# Contrastive Loss - Normal LL Mean: -1.7642
# Contrastive Loss - Anomalous LL Mean: 118.6082
# Contrastive Loss - Normal LL Mean: -10.9989
# Contrastive Loss - Anomalous LL Mean: 108.5449
# Contrastive Loss - Normal LL Mean: -10.2397
# Contrastive Loss - Anomalous LL Mean: 112.4435
# Contrastive Loss - Normal LL Mean: -8.5150
# Contrastive Loss - Anomalous LL Mean: 111.4876
# Contrastive Loss - Normal LL Mean: 1.5134
# Contrastive Loss - Anomalous LL Mean: 112.9889
#
# Epoch 9/10 — Loss: 111.0855
#  [L= 20] Acc=0.995  Prec=0.986  Rec=0.924  AUC=0.976  F1_PA=0.954  Thr=-25.834  ADD=2.00
#  [L= 50] Acc=0.994  Prec=0.989  Rec=0.915  AUC=0.981  F1_PA=0.951  Thr=-28.209  ADD=1.50
#  [L=100] Acc=0.994  Prec=0.989  Rec=0.922  AUC=0.986  F1_PA=0.955  Thr=-27.754  ADD=3.00
#  [L=200] Acc=0.992  Prec=0.980  Rec=0.909  AUC=0.977  F1_PA=0.943  Thr=-24.899  ADD=1.83
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Contrastive Loss - Normal LL Mean: -13.0814
# Contrastive Loss - Anomalous LL Mean: 111.9992
# Contrastive Loss - Normal LL Mean: -10.3364
# Contrastive Loss - Anomalous LL Mean: 110.1575
# Contrastive Loss - Normal LL Mean: -14.2696
# Contrastive Loss - Anomalous LL Mean: 111.0196
# Contrastive Loss - Normal LL Mean: -4.4090
# Contrastive Loss - Anomalous LL Mean: 111.6946
# Contrastive Loss - Normal LL Mean: -1.0364
# Contrastive Loss - Anomalous LL Mean: 112.8288
# Contrastive Loss - Normal LL Mean: -4.6584
# Contrastive Loss - Anomalous LL Mean: 111.6612
# Contrastive Loss - Normal LL Mean: -2.8744
# Contrastive Loss - Anomalous LL Mean: 109.2804
# Contrastive Loss - Normal LL Mean: -2.3887
# Contrastive Loss - Anomalous LL Mean: 111.2230
# Contrastive Loss - Normal LL Mean: -6.5337
# Contrastive Loss - Anomalous LL Mean: 112.4592
# Contrastive Loss - Normal LL Mean: -15.8886
# Contrastive Loss - Anomalous LL Mean: 103.7564
# Contrastive Loss - Normal LL Mean: -21.2465
# Contrastive Loss - Anomalous LL Mean: 103.5566
# Contrastive Loss - Normal LL Mean: -5.2772
# Contrastive Loss - Anomalous LL Mean: 110.5998
# Contrastive Loss - Normal LL Mean: 2.0281
# Contrastive Loss - Anomalous LL Mean: 114.1174
# Contrastive Loss - Normal LL Mean: -17.1802
# Contrastive Loss - Anomalous LL Mean: 107.3023
# Contrastive Loss - Normal LL Mean: -2.2975
# Contrastive Loss - Anomalous LL Mean: 109.6614
# Contrastive Loss - Normal LL Mean: -11.2857
# Contrastive Loss - Anomalous LL Mean: 107.3069
# Contrastive Loss - Normal LL Mean: -17.0499
# Contrastive Loss - Anomalous LL Mean: 105.6473
# Contrastive Loss - Normal LL Mean: 13.9468
# Contrastive Loss - Anomalous LL Mean: 114.0847
# Contrastive Loss - Normal LL Mean: -4.3029
# Contrastive Loss - Anomalous LL Mean: 109.2145
# Contrastive Loss - Normal LL Mean: -2.5701
# Contrastive Loss - Anomalous LL Mean: 108.4715
# Contrastive Loss - Normal LL Mean: -8.7334
# Contrastive Loss - Anomalous LL Mean: 106.2051
# Contrastive Loss - Normal LL Mean: -9.6431
# Contrastive Loss - Anomalous LL Mean: 104.3229
# Contrastive Loss - Normal LL Mean: -14.1562
# Contrastive Loss - Anomalous LL Mean: 107.5407
# Contrastive Loss - Normal LL Mean: 1.8297
# Contrastive Loss - Anomalous LL Mean: 107.2018
# Contrastive Loss - Normal LL Mean: -14.7152
# Contrastive Loss - Anomalous LL Mean: 104.0631
# Contrastive Loss - Normal LL Mean: -10.2564
# Contrastive Loss - Anomalous LL Mean: 106.7809
# Contrastive Loss - Normal LL Mean: -2.8706
# Contrastive Loss - Anomalous LL Mean: 103.4089
# Contrastive Loss - Normal LL Mean: -10.3231
# Contrastive Loss - Anomalous LL Mean: 105.9871
# Contrastive Loss - Normal LL Mean: -15.7380
# Contrastive Loss - Anomalous LL Mean: 103.0373
# Contrastive Loss - Normal LL Mean: 0.4705
# Contrastive Loss - Anomalous LL Mean: 111.3612
#
# Epoch 10/10 — Loss: 103.2853
#  [L= 20] Acc=0.996  Prec=0.991  Rec=0.945  AUC=0.983  F1_PA=0.967  Thr=-26.259  ADD=2.00
#  [L= 50] Acc=0.996  Prec=0.992  Rec=0.941  AUC=0.987  F1_PA=0.966  Thr=-27.915  ADD=1.50
#  [L=100] Acc=0.996  Prec=0.986  Rec=0.954  AUC=0.992  F1_PA=0.970  Thr=-25.372  ADD=2.67
#  [L=200] Acc=0.994  Prec=0.993  Rec=0.927  AUC=0.985  F1_PA=0.959  Thr=-27.284  ADD=1.83

# %%
from sklearn.manifold import TSNE
import seaborn as sns

def visualize_latent_space(model, loader, device, dataset_name="Dataset"):
    """
    This function visualizes the latent space by extracting embeddings from the model
    for each batch in 'loader'. We'll handle 3 batch-size scenarios:
      1) 5 items: (x1, x2, labels, x1_mask, x2_mask)
      2) 3 items: (x1, x2, labels)
      3) 2 items: (features, labels)
    We'll assume the model has a method 'get_embeddings(x1, x2, mask1, mask2)'
    that returns an embedding (e.g. shape (batch_size, embed_dim)).
    """

    import numpy as np
    import matplotlib.pyplot as plt
    import seaborn as sns
    import torch

    model.eval()

    all_embeddings = []
    all_labels     = []

    with torch.no_grad():
        for batch in loader:
            if len(batch) == 5:
                # (padded_x1, padded_x2, batch_labels, x1_mask, x2_mask)
                padded_x1, padded_x2, batch_labels, x1_mask, x2_mask = batch

                padded_x1 = padded_x1.to(device, dtype=torch.float32)
                padded_x2 = padded_x2.to(device, dtype=torch.float32)
                batch_labels = batch_labels.to(device)
                x1_mask = x1_mask.to(device)
                x2_mask = x2_mask.to(device)

                # We'll call some method get_embeddings() if your model has it
                embeddings = model.get_embeddings(padded_x1, padded_x2, mask1=x1_mask, mask2=x2_mask)

            elif len(batch) == 3:
                # (padded_x1, padded_x2, batch_labels)
                padded_x1, padded_x2, batch_labels = batch

                padded_x1 = padded_x1.to(device, dtype=torch.float32)
                padded_x2 = padded_x2.to(device, dtype=torch.float32)
                batch_labels= batch_labels.to(device)

                embeddings = model.get_embeddings(padded_x1, padded_x2)

            elif len(batch) == 2:
                # (features, labels)
                features, batch_labels = batch

                features = features.to(device, dtype=torch.float32)
                batch_labels= batch_labels.to(device)

                # If model expects two inputs, pass features twice
                # or adapt if your model uses a single input in get_embeddings
                embeddings = model.get_embeddings(features, features)

            else:
                raise ValueError(f"Unexpected number of items in batch: {len(batch)}")

            # Convert embeddings + labels to CPU
            emb_np = embeddings.cpu().numpy()
            lbl_np = batch_labels.cpu().numpy()

            all_embeddings.append(emb_np)
            all_labels.append(lbl_np)

    # Concat all
    all_embeddings = np.concatenate(all_embeddings, axis=0)  # shape (total_samples, embed_dim)
    all_labels     = np.concatenate(all_labels,     axis=0)  # shape (total_samples,)

    # Suppose we do a 2D visualization via e.g. TSNE
    from sklearn.manifold import TSNE
    tsne = TSNE(n_components=2, random_state=0)
    emb_2d = tsne.fit_transform(all_embeddings)

    # Plot
    plt.figure(figsize=(8,6))
    # separate normal vs anomaly for coloring
    normal_mask  = (all_labels == 0)
    anomaly_mask = (all_labels == 1)

    plt.scatter(emb_2d[normal_mask,0],  emb_2d[normal_mask,1],  c='blue',  alpha=0.5, label='Normal')
    plt.scatter(emb_2d[anomaly_mask,0], emb_2d[anomaly_mask,1], c='red',   alpha=0.5, label='Anomaly')

    plt.title(f"Latent Space Visualization - {dataset_name}")
    plt.legend()
    plt.show()

# %%
# Visualize the latent space for the training set
#visualize_latent_space(model, train_loader, device, dataset_name="Train")

# Visualize the latent space for the test set
visualize_latent_space(model, val_loader, device, dataset_name="Validation")
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
